# %%
# !python yolov5/detect.py --weights yolov5/runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source pred_images
# Out:
# detect: weights=['yolov5/runs/train/exp/weights/best.pt'], source=pred_images, data=yolov5/data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.10.10 torch-2.0.0 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# image 1/2 /Users/harsh/Downloads/SmartFridgeSystem/Yolo/pred_images/cabbage-that-ruined.png: 352x416 1 Stale Cabbage, 58.3ms
# image 2/2 /Users/harsh/Downloads/SmartFridgeSystem/Yolo/pred_images/compared.jpg: 192x416 2 Fresh Cabbages, 33.0ms
# Speed: 0.5ms pre-process, 45.7ms inference, 3.8ms NMS per image at shape (1, 3, 416, 416)
# ...

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('yolov5/runs/detect/exp3/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %%
# !pwd
# Out:
# /Users/harsh/Downloads/SmartFridgeSystem/Yolo
